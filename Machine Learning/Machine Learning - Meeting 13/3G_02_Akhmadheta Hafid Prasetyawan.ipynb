# %% [markdown]
# ### Identitas Diri :
# - NO/NIM : 02/2041720221
# - Nama  : Akhmadheta Hafid Prasetyawan
# - Kelas : TI 3G

# %% [markdown]
# ##### Studi Kasus
# Pada sebuah lembaga kemanusiaan berbasis teknologi informasi, dibentuk beberapa tim kemanusiaan yang bertugas untuk terjun ke masyarakat memberikan bantuan dalam bentuk aplikasi komputer atau layanan pelatihan IT.  Kegiatan tersebut dilaksanakan setiap tahun dengan ketentuan anggota organisasi tersebut dapat bergabung ke beberapa tim sebagai ketua atau anggota. Terdapat pula anggota yang sudah tidak aktif di organisasi tersebut (terhapus di database mereka —> label #N/A).  Organisasi tersebut juga melakukan rekrutmen volunteer, namun tidak semua tim menggunakan bantuan volunteer. Hasil kegiatan dari setiap tim dapat diwujudkan ke dalam sebuah pengakuan hak cipta atau publikasi karya ilmiah atau publikasi berita di media massa.
#
#
# Ketentuan:
#
# - Pengerjaan secara individu alias setiap mahasiswa!
# - terdapat data dengan nilai #N/A, pertimbangkan cara terbaik untuk mengatasi nilai tersebut.
# - Tidak boleh ada duplikasi pekerjaan antar mahasiswa (evaluasi pemahaman pengerjaan quiz 2 dilaksanakan pada Minggu ke-14)

# %% [markdown]
# #### Load Dataset

# %%
import pandas as pd

df = pd.read_csv('dataset_quiz.csv')

df.head()
# Out:
#    id_ketua  id_anggota1  id_anggota2  id_anggota3  id_anggota4  id_anggota5  \
# 0    7206.0       7214.0       6211.0       8602.0       7801.0          NaN
# 1    7214.0       7109.0       8402.0       7903.0       9202.0          NaN
# 2    5911.0       8201.0       8701.0       9101.0       9003.0          NaN
# 3    8402.0       7702.0       8602.0       8903.0       8903.0          NaN
# 4    8201.0       8305.0       5911.0       5903.0       8402.0          NaN
#
#   keterlibatan_vltr  jml_vltr_terlibat  tahun    skema luaran_hki  \
# 0             TIDAK                  0   2019  REGULER  TIDAK ADA
# 1             TIDAK                  0   2019  REGULER  TIDAK ADA
# 2             TIDAK                  0   2019  REGULER  TIDAK ADA
# 3             TIDAK                  0   2019  REGULER  TIDAK ADA
# 4             TIDAK                  0   2019  REGULER  TIDAK ADA
#
#   jenis_luaran_hki potensi_hki luaran_lain jenis_luaran_lain  \
# ...

# %%
print(df.dtypes)
# Out:
# id_ketua              float64
# id_anggota1           float64
# id_anggota2           float64
# id_anggota3           float64
# id_anggota4           float64
# id_anggota5           float64
# keterlibatan_vltr      object
# jml_vltr_terlibat       int64
# tahun                   int64
# skema                  object
# luaran_hki             object
# jenis_luaran_hki       object
# potensi_hki            object
# luaran_lain            object
# jenis_luaran_lain      object
# status_luaran_lain     object
# dtype: object

# %% [markdown]
# Diperlukan langkah untuk mengubah value NaN menjadi 0 dan mengubah tipe data dari id_ketua, id_anggota1, id_anggota2, id_anggota3, id_anggota4, id_anggota5, jml_vltr_terlibat, dan tahun menjadi int 32 untuk menyesuaikan dataset

# %%
# Mengatasi Nilai N/A
df = df.fillna(0)

# Menyesuaikan Tipe Data
convert_dict = {
    'id_ketua': int,
    'id_anggota1': int,
    'id_anggota2': int,
    'id_anggota3': int,
    'id_anggota4': int,
    'id_anggota5': int,
    'jml_vltr_terlibat' : int,
    'tahun' : int,
}
df = df.astype(convert_dict)

df.head()
# Out:
#    id_ketua  id_anggota1  id_anggota2  id_anggota3  id_anggota4  id_anggota5  \
# 0      7206         7214         6211         8602         7801            0
# 1      7214         7109         8402         7903         9202            0
# 2      5911         8201         8701         9101         9003            0
# 3      8402         7702         8602         8903         8903            0
# 4      8201         8305         5911         5903         8402            0
#
#   keterlibatan_vltr  jml_vltr_terlibat  tahun    skema luaran_hki  \
# 0             TIDAK                  0   2019  REGULER  TIDAK ADA
# 1             TIDAK                  0   2019  REGULER  TIDAK ADA
# 2             TIDAK                  0   2019  REGULER  TIDAK ADA
# 3             TIDAK                  0   2019  REGULER  TIDAK ADA
# 4             TIDAK                  0   2019  REGULER  TIDAK ADA
#
#   jenis_luaran_hki potensi_hki luaran_lain jenis_luaran_lain  \
# ...

# %%
print(df.dtypes)
# Out:
# id_ketua               int32
# id_anggota1            int32
# id_anggota2            int32
# id_anggota3            int32
# id_anggota4            int32
# id_anggota5            int32
# keterlibatan_vltr     object
# jml_vltr_terlibat      int32
# tahun                  int32
# skema                 object
# luaran_hki            object
# jenis_luaran_hki      object
# potensi_hki           object
# luaran_lain           object
# jenis_luaran_lain     object
# status_luaran_lain    object
# dtype: object

# %% [markdown]
# ##### 1. Buat 5 jenis visualisasi yang dapat dihasilkan dari dataset yang diberikan! (5 poin)

# %%
# Import Library Visualisasi
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### LINE PLOT

# %%
x = df['tahun'].unique().tolist()
print(x)

y = []

for item in x:
    y.append(len(df[df.tahun == item]))

print(y)

# create line plot
plt.plot(x,y, color='red', marker='o')
plt.title('Jumlah Tim dari Tahun ke Tahun\n', size=16)
plt.ylabel('\nJumlah Tim', size=14)
plt.xlabel('\nTahun', size=14)
plt.xticks(x)
plt.show()
# Out:
# [2019, 2020, 2021, 2022]
# [19, 22, 17, 27]

# %% [markdown]
# ###### BAR PLOT

# %%
x = df['jenis_luaran_lain'].unique().tolist()
print(x)

y = []

for item in x:
    y.append(len(df[df.jenis_luaran_lain == item]))

print(y)

# create line plot
plt.bar(x, y, color='red')
plt.title('Jumlah Jenis Luaran\n', size=16)
plt.ylabel('\nJumlah Tim', size=14)
plt.xlabel('\Jenis Luaran', size=14)

plt.show()
# Out:
# ['TIDAK ADA', 'Publikasi Media Massa', 'Artikel Ilmiah', 'Modul Ajar']
# [69, 5, 10, 1]

# %% [markdown]
# ###### STACKED BAR PLOT

# %%
x = df['tahun'].unique().tolist()

yno = []
yyes = []
for item in x:
    yno.append(len(df[(df.keterlibatan_vltr == 'TIDAK') & (df.tahun == item)]))
    yyes.append(len(df[(df.keterlibatan_vltr == 'YA') & (df.tahun == item)]))

fig, ax = plt.subplots()


ax.bar(x, yno, 0.35, label='Tidak')
ax.bar(x, yyes, 0.35, bottom=yno,
       label='Ya')

ax.set_ylabel('Jumlah')
ax.set_title('Jumlah Tim berdasarkan Keterlibatan Volunteer')
ax.legend()
plt.xticks(x)
plt.show()

# %% [markdown]
# ###### CAT PLOT

# %%
x = df['id_ketua'].unique().tolist()

y = []

for item in x:
    y.append(len(df[df.id_ketua == item]))

table = pd.DataFrame({
    'id_ketua' : x,
    'count' : y,
})

print("Top 5 Anggota Organisasi yang Paling Sering Menjabat sebgai Ketua Tim")
table[['id_ketua', 'count']].sort_values(by='count', ascending=False).head().reset_index(drop=True)

chart=sns.catplot(x="id_ketua", y="count", s=50, data=table[table.id_ketua != 0])
chart.set_xticklabels(rotation=90)

table.sort_values(by='count', ascending=False).head().reset_index(drop=True)
# Out:
# Top 5 Anggota Organisasi yang Paling Sering Menjabat sebgai Ketua Tim
#    id_ketua  count
# 0      8402      7
# 1      7206      4
# 2      8805      4
# 3      7214      4
# 4      8803      4

# %% [markdown]
# ###### PIE PLOT

# %%
label = df['potensi_hki'].unique().tolist()
x = []
colors = ("sandybrown", "wheat", "oldlace", "burlywood") 

for item in label:
    x.append(len(df[df.potensi_hki == item]))
print(x)

plt.pie(x, labels=label, colors=colors, autopct='%1.0f%%', pctdistance=0.8, startangle=90,
        textprops=dict(color="black"))

plt.legend(title="Potensi",loc="center left")
plt.show()
# Out:
# [70, 6, 1, 8]

# %% [markdown]
# #### Preprocessing Data

# %%
# Menggunakan LabelEncoder untuk mengkonversi nilai posisi menjadi urutan 
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

df['keterlibatan_vltr'] = labelencoder.fit_transform(df['keterlibatan_vltr'])
df['skema'] = labelencoder.fit_transform(df['skema'])
df['luaran_hki'] = labelencoder.fit_transform(df['luaran_hki'])
df['jenis_luaran_hki'] = labelencoder.fit_transform(df['jenis_luaran_hki'])
df['potensi_hki'] = labelencoder.fit_transform(df['potensi_hki'])
df['luaran_lain'] = labelencoder.fit_transform(df['luaran_lain'])
df['jenis_luaran_lain'] = labelencoder.fit_transform(df['jenis_luaran_lain'])
df['status_luaran_lain'] = labelencoder.fit_transform(df['status_luaran_lain'])

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(30,20)) 

sns.heatmap(df.corr(), cmap='YlGnBu', annot = True, linewidths=.7, ax=ax)
plt.show()

# %% [markdown]
# ##### 2. Lakukan pemilahan data training dan testing yang sesuai dan proporsional dari data tersebut! (5 poin)
# ##### 3. Tentukan data validasi! (5 poin)

# %%
# Split data
from sklearn.model_selection import train_test_split

# Split data training dan dan lainnya
# data lainnya, akan kita split lagi menjadi validasi dan testing.
# Rasio yang akan kita gunakan adalah 8:1:1
df_train, df_unseen = train_test_split(df, test_size=0.2, random_state=0, stratify=df['status_luaran_lain'])

# Split lagi antara validasi dan testing
df_val, df_test = train_test_split(df_unseen, test_size=0.5, random_state=0, stratify=df_unseen['status_luaran_lain'])

# Cek masing-masing ukuran data

print(f'Jumlah label data asli:\n{df.status_luaran_lain.value_counts()}\n')
# Data Training dan Testing (Nomor 2)
print(f'Jumlah label data train:\n{df_train.status_luaran_lain.value_counts()}')
print(f'Jumlah label data test:\n{df_test.status_luaran_lain.value_counts()}\n')
# Data Validasi
print(f'Jumlah label data val:\n{df_val.status_luaran_lain.value_counts()}')
# Out:
# Jumlah label data asli:
# 1    70
# 2    13
# 0     2
# Name: status_luaran_lain, dtype: int64
#
# Jumlah label data train:
# 1    56
# 2    10
# 0     2
# Name: status_luaran_lain, dtype: int64
# Jumlah label data test:
# 1    7
# 2    2
# Name: status_luaran_lain, dtype: int64
#
# Jumlah label data val:
# 1    7
# 2    1
# Name: status_luaran_lain, dtype: int64

# %% [markdown]
# ##### 3. Tentukan data validasi! (5 poin)

# %%
df.head()
# Out:
#    id_ketua  id_anggota1  id_anggota2  id_anggota3  id_anggota4  id_anggota5  \
# 0      7206         7214         6211         8602         7801            0
# 1      7214         7109         8402         7903         9202            0
# 2      5911         8201         8701         9101         9003            0
# 3      8402         7702         8602         8903         8903            0
# 4      8201         8305         5911         5903         8402            0
#
#    keterlibatan_vltr  jml_vltr_terlibat  tahun  skema  luaran_hki  \
# 0                  0                  0   2019      1           1
# 1                  0                  0   2019      1           1
# 2                  0                  0   2019      1           1
# 3                  0                  0   2019      1           1
# 4                  0                  0   2019      1           1
#
#    jenis_luaran_hki  potensi_hki  luaran_lain  jenis_luaran_lain  \
# ...

# %% [markdown]
# ##### 4. Terapkan dua jenis metode klasifikasi dan lakukan perbandingan akurasi  dengan wajib melibatkan variabel keterlibatan volunteer sampai variabel luaran-luaran yang dihasilkan! (20 poin)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# # Memisahkan label dan fitur
# X = df.iloc[:, 6:14] 
# y = df.iloc[:, 15] 

# X untuk kolom index ke-1 dst
X_train = df_train.iloc[:, 6:14]
X_test = df_test.iloc[:, 6:14] 
# y untuk kolom index ke-15
y_train = df_train.iloc[:, 15] 
y_test = df_test.iloc[:, 15]

# DT ENTROPY
dt_entropy = DecisionTreeClassifier(criterion='entropy')

# Fit Model
dt_entropy.fit(X_train, y_train)

# Memprediksi label set test
y_pred_entropy = dt_entropy.predict(X_test)

# Evaluasi
acc_entropy = accuracy_score(y_test, y_pred_entropy)

print(f'Akurasi DT Entropy: {acc_entropy}')

# RANDOM FOREST
rf = RandomForestClassifier(n_estimators=10, random_state=50)

# Fit Model
rf.fit(X_train, y_train)

# Memprediksi label set test
y_pred_rf = rf.predict(X_test)

# Evaluasi
acc_rf = accuracy_score(y_test, y_pred_rf)
print(f'Akurasi Random Forest: {acc_rf}')
# Out:
# Akurasi DT Entropy: 0.8888888888888888
# Akurasi Random Forest: 1.0

# %% [markdown]
# Dari hasil akurasi tersebut, dapat dilihat bahwa model DT menggunakan entropy menghasilkan akurasi yang lebih baik dari pada model Random Forest

# %% [markdown]
# ##### 5. Terapkan sebuah metode prediksi (berdasarkan tahun, misal: jumlah kegiatan pada tahun tertentu sebagai x dan jumlah  luaran sebagai y) serta hitung akurasinya dengan wajib melibatkan variabel keterlibatan volunteer sampai variabel luaran-luaran yang dihasilkan! (20 poin)

# %% [markdown]
# Membuat dataset baru berdasarkan dataset kuis untuk metode prediksi dalam menentukan jumlah status luaran (Draft dan Terpublikasi)

# %%
df = pd.read_csv('dataset_quiz.csv')


dfp = pd.DataFrame(list())

dfp['tahun'] = df['tahun'].unique()

jml_tim = []
jml_vltr = []
reg = []
kem = []
jml_luaran_hki = []
jml_hak_cipta = []
ptn_ya = []
ptn_tdk = []
ptn_sdh = []
ptn_drf = []
jml_luaran_lain = []
jml_artikel = []
jml_media_massa = []
jml_modul_ajar = []
jml_status_draft_terpublikasi = []

for item in dfp['tahun']:
    slice = df[df.tahun == item]
    jml_tim.append(len(slice))
    jml_vltr.append(sum(slice['jml_vltr_terlibat']))
    reg.append(len(df[(df.tahun == item) & (df.skema == "REGULER")]))
    kem.append(len(df[(df.tahun == item) & (df.skema == "KEMITRAAN")]))
    jml_luaran_hki.append(len(df[(df.tahun == item) & (df.luaran_hki == "ADA")]))
    jml_hak_cipta.append(len(df[(df.tahun == item) & (df.jenis_luaran_hki== "Hak Cipta")]))
    ptn_ya.append(len(df[(df.tahun == item) & (df.potensi_hki == "YA")]))
    ptn_tdk.append(len(df[(df.tahun == item) & (df.potensi_hki == "TIDAK")]))
    ptn_sdh.append(len(df[(df.tahun == item) & (df.potensi_hki == "SUDAH")]))
    ptn_drf.append(len(df[(df.tahun == item) & (df.potensi_hki == "DRAFT")]))
    jml_luaran_lain.append(len(df[(df.tahun == item) & (df.luaran_lain == "YA")]))
    jml_artikel.append(len(df[(df.tahun == item) & (df.jenis_luaran_lain == "Artikel Ilmiah")]))
    jml_media_massa.append(len(df[(df.tahun == item) & (df.jenis_luaran_lain == "Publikasi Media Massa")]))
    jml_modul_ajar.append(len(df[(df.tahun == item) & (df.jenis_luaran_lain == "Modul Ajar")]))
    jml_status_draft_terpublikasi.append(len(slice[(slice.status_luaran_lain == "Terpublikasi") | (slice.status_luaran_lain == "Draft")]))


dfp['jml_tim'] = jml_tim
dfp['jml_vltr'] = jml_vltr
dfp['reg'] = reg
dfp['kem'] = kem
dfp['jml_luaran_hki'] = jml_luaran_hki
dfp['jml_hak_cipta'] = jml_hak_cipta
dfp['ptn_ya'] = ptn_ya
dfp['ptn_tdk'] = ptn_tdk
dfp['ptn_sdh'] = ptn_sdh
dfp['ptn_drf'] = ptn_drf
dfp['jml_luaran_lain'] = jml_luaran_lain
dfp['jml_artikel'] = jml_artikel
dfp['jml_media_massa'] = jml_media_massa
dfp['jml_modul_ajar'] = jml_modul_ajar
dfp['jml_status_draft_terpublikasi'] = jml_status_draft_terpublikasi 

dfp.to_csv('dataset_prediksi.csv')
dfp.head()
# Out:
#    tahun  jml_tim  jml_vltr  reg  kem  jml_luaran_hki  jml_hak_cipta  ptn_ya  \
# 0   2019       19         0   19    0               0              0       0
# 1   2020       22        39   20    2               4              4       5
# 2   2021       17        26   16    1               1              1       2
# 3   2022       27        49   25    2               3              3       1
#
#    ptn_tdk  ptn_sdh  ptn_drf  jml_luaran_lain  jml_artikel  jml_media_massa  \
# 0       19        0        0                0            0                0
# 1       13        3        1               10            8                1
# 2       14        1        0                3            1                2
# 3       24        2        0                3            1                2
#
#    jml_modul_ajar  jml_status_draft_terpublikasi
# 0               0                              0
# 1               1                              9
# 2               0                              3
# ...

# %%
fig, ax = plt.subplots(figsize=(30,20)) 
sns.heatmap(dfp.corr(), cmap='YlGnBu', annot = True, linewidths=.7, ax=ax)
plt.show()

# %%
X = dfp[['jml_modul_ajar', 'jml_vltr', 'jml_luaran_hki', 'jml_modul_ajar', 'jml_artikel', 'jml_luaran_lain', 'ptn_drf', 'ptn_ya', 'ptn_sdh']]
y = dfp['jml_status_draft_terpublikasi']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

from sklearn.ensemble import RandomForestRegressor
import numpy as np
regressor = RandomForestRegressor(n_estimators = 1000, random_state = 42)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

# Evaluasi
# Calculate the absolute errors
errors = abs(y_pred - y_test)

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 83.95 %.

# %% [markdown]
# ##### 6. Buat Confusion Matrix dan ROC berdasarkan klasifikasi yang diterapkan pada nomor 4! (15 poin)

# %% [markdown]
# ##### 7. Lakukan hyperparameter tunning berdasarkan jawaban nomor 2, 3, dan 4 menggunakan metode Grid Search, Random Search, dan Exhausive Search! (20 poin)

# %%
# Memisahkan label dan fitur
X = df.iloc[:, 6:14] # X untuk kolom index ke-1 dst
y = df.iloc[:, 15] # y untuk kolom index ke-15

from sklearn.model_selection import RepeatedKFold

# Inisiasi repated k-fold
rkf = RepeatedKFold(n_splits=4, n_repeats=3, random_state=42)

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

# inisiasi model
dt = DecisionTreeClassifier()

# Definisikan hyperparameter yang akan digunakan
# sklearn menerima dalam bentuk dictionary
# nama hyperparamater HARUS SESUAI dengan dokumentasi sklearn
params = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': list(range(5, 11)),
}

# inisiasi rs berdasarkan nilai repeated k-fold dan hyperparameter
rs = RandomizedSearchCV(dt, param_distributions=params,
                        n_iter=10, scoring="accuracy",
                        n_jobs=-1, cv=rkf, return_train_score=True)

# Fit / latih berdasarkan random
# %timeit merupakan magic command didalam ipython notebook
# yang dapat kita gunakan untuk menghitung waktu komputasi
# cara ini cukup efektif untuk melakukan evaluasi suatu algoritma atau prosedur
# %timeit rs.fit(X, y)

# Evaluasi dengan score
score = rs.score(X, y)

print(f'Hasil evaluasi: {score}')
print(f'Konfigurasi hyperparameter: {rs.best_params_}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [50], line 33
#      25 rs = RandomizedSearchCV(dt, param_distributions=params,
#      26                         n_iter=10, scoring="accuracy",
#      27                         n_jobs=-1, cv=rkf, return_train_score=True)
#      29 # Fit / latih berdasarkan random
#      30 # %timeit merupakan magic command didalam ipython notebook
#      31 # yang dapat kita gunakan untuk menghitung waktu komputasi
#      32 # cara ini cukup efektif untuk melakukan evaluasi suatu algoritma atau prosedur
# ---> 33 get_ipython().run_line_magic('timeit', 'rs.fit(X, y)')
#      35 # Evaluasi dengan score
#      36 score = rs.score(X, y)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2364, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
# ...

# %% [markdown]
# ##### 8. Tambahkan visualisasi berdasarkan nomor 4 dan 5 (masing-masing nomor minimal satu visualisasi)! (10 poin)
