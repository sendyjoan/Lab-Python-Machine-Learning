# %%
fn="input.txt" 
queries = [] 
knowledge_base = [] 
f1=open(fn, "r") 
input = f1.readlines() 
input = [x.strip() for x in input] 
 
for i in range(1, int(input[0]) + 1): 
 queries.append(input[i].replace(" ", "")) 
for i in range(int(input[0]) + 2, int(input[int(input[0]) + 1]) + int(input[0]) + 2): 
 knowledge_base.append(input[i].replace(" ", "")) 
knowledge_base = standardize_variables(knowledge_base)
 
kb = {} 
list_of_predicates = [] 
add_to_kb(knowledge_base) 
 
fileOut = open("output.txt", "w") 
for query in queries: 
 result = fol_bc_ask(query, {}) 
 if result != None: 
  print("True", result) 
  fileOut.write("TRUE" + "\n") 
 else: 
  print("False", result) 
  fileOut.write("FALSE" + "\n") 
 
fileOut.close() 
f1.close
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a372a18c74c8> in <module>()
#      10 for i in range(int(input[0]) + 2, int(input[int(input[0]) + 1]) + int(input[0]) + 2):
#      11  knowledge_base.append(input[i].replace(" ", ""))
# ---> 12 knowledge_base = standardize_variables(knowledge_base)
#      13
#      14 kb = {}
#
# NameError: name 'standardize_variables' is not defined
