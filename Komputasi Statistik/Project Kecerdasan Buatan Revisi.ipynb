# %%
global facts
global is_changed

is_changed = True
facts0 = [["GP01","FALSE"], ["GP02", "FALSE"],	["GP03", "FALSE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"],	["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"],	["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "FALSE"],	["GP19", "FALSE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "FALSE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "FALSE"],	["GP33", "FALSE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]
# Sakit Kudis
facts1 = [["GP01","FALSE"], ["GP02", "FALSE"],	["GP03", "FALSE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"], ["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"], ["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "FALSE"],	["GP19", "FALSE"], ["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"], ["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "TRUE"], ["GP29", "TRUE"], ["GP30", "TRUE"],
           ["GP31", "TRUE"], ["GP32", "FALSE"], ["GP33", "FALSE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]

# Helminthiasis
facts2 = [["GP01","FALSE"], ["GP02", "FALSE"],	["GP03", "FALSE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"],	["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"],	["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "TRUE"],	["GP19", "FALSE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "TRUE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "FALSE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "FALSE"],	["GP33", "FALSE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]

# Flu
facts3 = [["GP01","TRUE"], ["GP02", "FALSE"],	["GP03", "TRUE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "TRUE"],	["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"],	["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "FALSE"],	["GP19", "FALSE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "FALSE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "FALSE"],	["GP33", "FALSE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]

# Diare
facts4 = [["GP01","TRUE"], ["GP02", "TRUE"],	["GP03", "TRUE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"],	["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"],	["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "FALSE"],	["GP19", "FALSE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "FALSE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "FALSE"],	["GP33", "FALSE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]

# Patah Tulang
facts5 = [["GP01","FALSE"], ["GP02", "FALSE"],	["GP03", "FALSE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"],	["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "TRUE"],	["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "TRUE"],	["GP19", "FALSE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "FALSE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "FALSE"],	["GP33", "FALSE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]

# Orf
facts6 = [["GP01","FALSE"], ["GP02", "FALSE"],	["GP03", "FALSE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"],	["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"],	["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "FALSE"],	["GP19", "FALSE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "FALSE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "TRUE"],	["GP33", "FALSE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "TRUE"]]

# Pink Eye
facts7 = [["GP01","FALSE"], ["GP02", "FALSE"],	["GP03", "FALSE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"],	["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"],	["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "FALSE"],	["GP19", "FALSE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "FALSE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "FALSE"],	["GP33", "FALSE"], ["GP34", "TRUE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]

# Brucellosis
facts8 = [["GP01","FALSE"], ["GP02", "FALSE"],	["GP03", "FALSE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"],	["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"],	["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "TRUE"],	["GP19", "FALSE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "TRUE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "FALSE"],	["GP33", "FALSE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "TRUE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]

# Infectious Bovine Rhinotracheitiss
facts9 = [["GP01","FALSE"], ["GP02", "FALSE"],	["GP03", "FALSE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"],	["GP10", "TRUE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"],	["GP15", "FALSE"],
           ["GP16", "TRUE"],	["GP17", "FALSE"], ["GP18", "FALSE"],	["GP19", "FALSE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "FALSE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "FALSE"],	["GP33", "TRUE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]

# Paratubercolosis
facts10 = [["GP01","FALSE"], ["GP02", "FALSE"],	["GP03", "FALSE"], ["GP04", "FALSE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"],	["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"],	["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "FALSE"],	["GP19", "TRUE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "TRUE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "FALSE"],	["GP33", "FALSE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]

# Gastroenteritis
facts11 = [["GP01","FALSE"], ["GP02", "FALSE"],	["GP03", "TRUE"], ["GP04", "TRUE"],	["GP05", "FALSE"],
           ["GP06", "FALSE"],	["GP07", "FALSE"], ["GP08", "FALSE"],	["GP09", "FALSE"],	["GP10", "FALSE"],
           ["GP11", "FALSE"],	["GP12", "FALSE"], ["GP13", "FALSE"],	["GP14", "FALSE"],	["GP15", "FALSE"],
           ["GP16", "FALSE"],	["GP17", "FALSE"], ["GP18", "FALSE"],	["GP19", "FALSE"],	["GP20", "FALSE"],
           ["GP21", "FALSE"],	["GP22", "FALSE"], ["GP23", "FALSE"],	["GP24", "FALSE"],	["GP25", "FALSE"],
           ["GP26", "FALSE"],	["GP27", "FALSE"], ["GP28", "FALSE"], ["GP29", "FALSE"], ["GP30", "FALSE"],
           ["GP31", "FALSE"], ["GP32", "FALSE"],	["GP33", "FALSE"], ["GP34", "FALSE"], ["GP35", "FALSE"],
           ["GP36", "FALSE"], ["GP37", "FALSE"], ["GP38", "FALSE"], ["GP39", "FALSE"], ["GP40", "FALSE"]]

def assert_fact(fact):
     global facts
     global is_changed
     if not fact in facts:
        facts += [fact]
        is_changed = True
        
while is_changed:
    is_changed = False
    for A1 in facts:
        if ["GP28", "TRUE"] in facts and ["GP29", "TRUE"] in facts and ["GP30", "TRUE"] in facts and ["GP31", "TRUE"] in facts:
            assert_fact(["Penyakit", "Kudis"])
            assert_fact(["Obat", "Kudix 120Ml"])
        elif ["GP18", "TRUE"] in facts and ["GP26", "TRUE"] in facts:
            assert_fact(["Penyakit", "Helminthiasis (cacingan)"])
            assert_fact(["Obat", "Vermixion 120Ml"])
        elif ["GP01", "TRUE"] in facts and ["GP03", "TRUE"] in facts and ["GP09", "TRUE"] in facts:
            assert_fact(["Penyakit", "Flu"])
            assert_fact(["Obat", "Fludoxin"])
        elif ["GP01", "TRUE"] in facts and ["GP02", "TRUE"] in facts and ["GP03", "TRUE"] in facts:
            assert_fact(["Penyakit", "Diare"])
            assert_fact(["Obat", "Diarex"])
        elif ["GP14", "TRUE"] in facts and ["GP18","TRUE"] in facts:
            assert_fact(["Penyakit","Patah Tulang"]) 
            assert_fact(["Obat","Supra Bone 40"])
        elif ["GP32", "TRUE"] in facts and ["GP40","TRUE"] in facts:
            assert_fact(["Penyakit","ORF"]) 
            assert_fact(["Obat","Gentavent 10gr"])
        elif ["GP34", "TRUE"] in facts:
            assert_fact(["Penyakit","Pink eye "]) 
            assert_fact(["Obat","Oxytetracycline injeksi"])
        elif ["GP18", "TRUE"] in facts and ["GP29", "TRUE"] in facts and ["GP37", "TRUE"] in facts:
            assert_fact(["Penyakit", "Brucellosis "])
            assert_fact(["Obat", "Calcidex Oral 100ml"])
        elif ["GP10", "TRUE"] in facts and ["GP33", "TRUE"] in facts and ["GP16", "TRUE"] in facts:
            assert_fact(["Penyakit", " Infectious Bovine Rhinotracheitiss "])
            assert_fact(["Obat", "Hiprabovis"])
        elif ["GP29", "TRUE"] in facts and ["GP19","TRUE"] in facts:
            assert_fact(["Penyakit","Paratuberculosis"]) 
            assert_fact(["Obat","Roxine 100 ml"])
        elif ["GP03", "TRUE"] in facts and ["GP04","TRUE"] in facts:
            assert_fact(["Penyakit","Gastroenteritis"]) 
            assert_fact(["Obat","Pilocarpin 5  ml"])
        else :
            assert_fact(["Penyakit", "Tidak Terdeteksi"])
            assert_fact(["Obat", "Konsultasi Dengan Dokter Terdekat"])
            
print("Hasil Diagnosa : ")
print("Kambing Terdiagnosa Penyakit "+facts[40][1])
print("Disarankan mengobati dengan "+facts[41][1])
# Out:
# Hasil Diagnosa :
# Kambing Terdiagnosa Penyakit Gastroenteritis
# Disarankan mengobati dengan Pilocarpin 5  ml
